# %% [markdown]
# <h2>Titanic Detanexa</h2>

# %%
# %pip install pandas
# %pip install matplotlib
# %pip install numpy
# %pip install scikit-learn
# %pip install xlrd
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h4>Cleaning the dataset</h4>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

titanic_data = pd.read_csv('Titanic_data/titanic3.csv', sep=';')
titanic_data.head(20)
# Out:
#     pclass  survived                                               name  sex  \
# 0        1         1                      Allen. Miss. Elisabeth Walton    2
# 1        1         1                     Allison. Master. Hudson Trevor    1
# 2        1         0                       Allison. Miss. Helen Loraine    2
# 3        1         0               Allison. Mr. Hudson Joshua Creighton    1
# 4        1         0    Allison. Mrs. Hudson J 2 (Bessie Waldo Daniels)    2
# 5        1         1                                Anderson. Mr. Harry    1
# 6        1         1                  Andrews. Miss. Kornelia Theodosia    2
# 7        1         0                             Andrews. Mr. Thomas Jr    1
# 8        1         1      Appleton. Mrs. Edward Dale (Charlotte Lamson)    2
# 9        1         0                            Artagaveytia. Mr. Ramon    1
# 10       1         0                             Astor. Col. John Jacob    1
# ...

# %%
titanic_data.describe()
# Out:
#             pclass     survived          sex          age        sibsp  \
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean      2.294882     0.381971     1.355997    29.881135     0.498854
# std       0.837836     0.486055     0.478997    14.413500     1.041658
# min       1.000000     0.000000     1.000000     0.166700     0.000000
# 25%       2.000000     0.000000     1.000000    21.000000     0.000000
# 50%       3.000000     0.000000     1.000000    28.000000     0.000000
# 75%       3.000000     1.000000     2.000000    39.000000     1.000000
# max       3.000000     1.000000     2.000000    80.000000     8.000000
#
#              parch         fare     embarked        body
# count  1309.000000  1308.000000  1307.000000  121.000000
# mean      0.385027    33.295479     1.394797  160.809917
# std       0.865560    51.758668     0.653817   97.696922
# min       0.000000     0.000000     1.000000    1.000000
# ...

# %%
# Pie chart showing how many male and female were on the titanic

genders = titanic_data["sex"]

female = []
male = []

for gender in genders:
    if gender == "male":
        male.append(gender)
    else:
        female.append(gender)
labels = ["female","male"]
count_female = np.array(len(female))
count_male = np.array(len(male))
plot_size = [count_female,count_male]
explode = (0.1,0)
fig,ax = plt.subplots()
ax.pie(plot_size,labels=labels, explode = explode, autopct='%1.1f%%',colors=["purple","blue"],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1790c4d60>,
# ...
#  [Text(-1.2000000000000002, 1.469576158976824e-16, 'female'),
#   Text(1.1, -2.6942229581241775e-16, 'male')],
#  [Text(-0.7, 8.572527594031472e-17, '100.0%'),
#   Text(0.6, -1.4695761589768238e-16, '0.0%')])

# %%
# change the name of columns for btter understanding

titanic_data.columns = ["passenger_class","survived","name","sex","age","number_of_siblings","number_of_parents","ticket","fare","cabin","embarked","boat","body","destination"]

# %%
# change the male and female to 1 and 0 respectively on the sex columns
filter_female = (titanic_data["sex"] == "female")
titanic_data.loc[filter_female,"sex"] = 0
filter_male = (titanic_data["sex"] == "male")
titanic_data.loc[filter_male,"sex"] = 1

# %%
# rounding up the age column to remove the decimal places

titanic_data_round_up_ge  = (titanic_data["age"] > 0)
titanic_data.loc[titanic_data_round_up_ge,"age"] = round(titanic_data["age"])
# All null values replaced with the number 0
titanic_data.fillna(0,inplace=True)
titanic_data.tail(10)
# Out:
#       passenger_class  survived                                     name  sex  \
# 1299                3         0                      Yasbeck. Mr. Antoni    1
# 1300                3         1  Yasbeck. Mrs. Antoni (Selini Alexander)    2
# 1301                3         0                     Youseff. Mr. Gerious    1
# 1302                3         0                        Yousif. Mr. Wazli    1
# 1303                3         0                    Yousseff. Mr. Gerious    1
# 1304                3         0                     Zabour. Miss. Hileni    2
# 1305                3         0                    Zabour. Miss. Thamine    2
# 1306                3         0                Zakarian. Mr. Mapriededer    1
# 1307                3         0                      Zakarian. Mr. Ortin    1
# 1308                3         0                       Zimmerman. Mr. Leo    1
#
#        age  number_of_siblings  number_of_parents  ticket     fare cabin  \
# ...

# %% [markdown]
# <h4>1. AWS model</h4>

# %% [markdown]
# <h4>2. PyCaret model</h4>

# %% [markdown]
# <h4>3. Sklearn</h4>

# %% [markdown]
# First we will import the neccesary Sklearn libraries. For the titanic dataset we will use a gradient boosting technique. This technique handles missing values by default!

# %%
import pandas as pd
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# Now we will load our titanic dataset with the seperator ";"

# %% [markdown]
# Now we will split out dataset into a test and traning set.

# %%
# Split the data into training and test sets.
X_train, X_test, y_train, y_test = train_test_split(
    titanic_data.drop(columns=['survived', 'name', 'embarked', 'boat', 'ticket', 'cabin', 'destination']),
    titanic_data['survived'],
    test_size=0.2,
    random_state=42)

# %% [markdown]
# Finally we will train our model with a max depth of 20.

# %%
# Model
clf = HistGradientBoostingClassifier(max_depth=20)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %% [markdown]
# Now we print our accuracy to easily compare it to the models above.

# %%
accuracy = clf.score(X_test, y_test)

# Print the accuracy of the model.
print("Accuracy: {:.2f}%".format(accuracy))
# Out:
# Accuracy: 0.81%
